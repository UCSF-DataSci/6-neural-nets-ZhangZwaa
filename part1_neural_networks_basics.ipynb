# %% [markdown]
# # Part 1: Neural Networks Basics
#
# ## Introduction
#
# In this part, you'll implement a simple neural network for EMNIST character recognition. This will help you understand the fundamentals of neural networks, including dense layers, activation functions, and dropout.
#
# ## Learning Objectives
#
# - Load and preprocess EMNIST dataset
# - Implement a simple neural network with dense layers
# - Train and evaluate the model
# - Save model and metrics in the correct format
#
# ## Setup and Installation

# %%
# Install required packages
# %pip install -r requirements.txt

# Import necessary libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from emnist import extract_training_samples, extract_test_samples


# Set random seeds for reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# Configure matplotlib for better visualization
# plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12

# Create directories
os.makedirs('models', exist_ok=True)
os.makedirs('results/part_1', exist_ok=True)
os.makedirs('logs', exist_ok=True)
# Out:
# Requirement already satisfied: pytest in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from -r requirements.txt (line 4)) (8.3.5)
# Requirement already satisfied: nbformat in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from -r requirements.txt (line 7)) (5.10.4)
# Requirement already satisfied: ipykernel in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from -r requirements.txt (line 8)) (6.29.5)
# Requirement already satisfied: nbclient in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from -r requirements.txt (line 9)) (0.10.2)
# Requirement already satisfied: pandas<3.0,>=1.5 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from -r requirements.txt (line 12)) (2.2.3)
# Requirement already satisfied: numpy<3.0,>=1.20 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from -r requirements.txt (line 13)) (2.1.3)
# Requirement already satisfied: scikit-learn<2.0,>=1.0 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from -r requirements.txt (line 14)) (1.6.1)
# Requirement already satisfied: xgboost<3.0,>=1.5 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from -r requirements.txt (line 15)) (2.1.4)
# Requirement already satisfied: imbalanced-learn<1.0,>=0.9 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from -r requirements.txt (line 16)) (0.13.0)
# Requirement already satisfied: matplotlib<4.0,>=3.5 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from -r requirements.txt (line 17)) (3.10.3)
# Requirement already satisfied: seaborn<1.0,>=0.11 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from -r requirements.txt (line 18)) (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from pandas<3.0,>=1.5->-r requirements.txt (line 12)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from pandas<3.0,>=1.5->-r requirements.txt (line 12)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from pandas<3.0,>=1.5->-r requirements.txt (line 12)) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from scikit-learn<2.0,>=1.0->-r requirements.txt (line 14)) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from scikit-learn<2.0,>=1.0->-r requirements.txt (line 14)) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from scikit-learn<2.0,>=1.0->-r requirements.txt (line 14)) (3.6.0)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from imbalanced-learn<1.0,>=0.9->-r requirements.txt (line 16)) (0.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from matplotlib<4.0,>=3.5->-r requirements.txt (line 17)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from matplotlib<4.0,>=3.5->-r requirements.txt (line 17)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from matplotlib<4.0,>=3.5->-r requirements.txt (line 17)) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from matplotlib<4.0,>=3.5->-r requirements.txt (line 17)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from matplotlib<4.0,>=3.5->-r requirements.txt (line 17)) (25.0)
# Requirement already satisfied: pillow>=8 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from matplotlib<4.0,>=3.5->-r requirements.txt (line 17)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from matplotlib<4.0,>=3.5->-r requirements.txt (line 17)) (3.2.3)
# Requirement already satisfied: colorama in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from pytest->-r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: iniconfig in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from pytest->-r requirements.txt (line 4)) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from pytest->-r requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from nbformat->-r requirements.txt (line 7)) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from nbformat->-r requirements.txt (line 7)) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from nbformat->-r requirements.txt (line 7)) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from nbformat->-r requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: comm>=0.1.1 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 8)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 8)) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 8)) (9.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 8)) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 8)) (0.1.7)
# Requirement already satisfied: nest-asyncio in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 8)) (1.6.0)
# Requirement already satisfied: psutil in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 8)) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 8)) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from ipykernel->-r requirements.txt (line 8)) (6.4.2)
# Requirement already satisfied: decorator in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (2.19.1)
# Requirement already satisfied: stack_data in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.6.3)
# Requirement already satisfied: wcwidth in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from jsonschema>=2.6->nbformat->-r requirements.txt (line 7)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from jsonschema>=2.6->nbformat->-r requirements.txt (line 7)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from jsonschema>=2.6->nbformat->-r requirements.txt (line 7)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from jsonschema>=2.6->nbformat->-r requirements.txt (line 7)) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->-r requirements.txt (line 7)) (4.3.8)
# Requirement already satisfied: pywin32>=300 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->-r requirements.txt (line 7)) (310)
# Requirement already satisfied: six>=1.5 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.5->-r requirements.txt (line 12)) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->-r requirements.txt (line 7)) (4.13.2)
# Requirement already satisfied: executing>=1.2.0 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: pure-eval in d:\homework\ds223\6-neural-nets-zhangzwaa\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1. Data Loading and Preprocessing

# %%
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np

# Load EMNIST 'letters' dataset
(emnist_dataset_train, emnist_dataset_test), emnist_info = tfds.load(
    'emnist/letters',
    split=['train', 'test'],
    as_supervised=True,
    with_info=True
)

# Convert training set to NumPy arrays
x_train = []
y_train = []
for img, label in tfds.as_numpy(emnist_dataset_train):
    img = np.squeeze(img)  # Shape: (28, 28)
    x_train.append(img)
    y_train.append(label)

x_train = np.array(x_train)
y_train = np.array(y_train)

# Convert test set to NumPy arrays
x_test = []
y_test = []
for img, label in tfds.as_numpy(emnist_dataset_test):
    img = np.squeeze(img)
    x_test.append(img)
    y_test.append(label)

x_test = np.array(x_test)
y_test = np.array(y_test)

# Print dataset information
print(f"Training data shape: {x_train.shape}")
print(f"Test data shape: {x_test.shape}")
print(f"Number of classes: {emnist_info.features['label'].num_classes}")

# Plot sample images from training data
plt.figure(figsize=(15, 5))
for i in range(5):
    plt.subplot(1, 5, i + 1)
    plt.imshow(x_train[i].T, cmap='gray')  # Transposed for correct orientation
    plt.title(f'Label: {chr(y_train[i] + 64)}')  # EMNIST 'letters' labels: 1=A
    plt.axis('off')
plt.show()
# Out:
# Training data shape: (88800, 28, 28)
# Test data shape: (14800, 28, 28)
# Number of classes: 37

# %%
# Preprocess data
# Normalize pixel values
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape for dense layers
x_train = x_train.reshape(-1, 28 * 28)
x_test = x_test.reshape(-1, 28 * 28)

# Convert labels to one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train - 1, num_classes=26)
y_test = tf.keras.utils.to_categorical(y_test - 1, num_classes=26)

# Split training data into train and validation
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, test_size=0.2, random_state=42
)

print(f"Preprocessed training data shape: {x_train.shape}")
print(f"Preprocessed validation data shape: {x_val.shape}")
print(f"Preprocessed test data shape: {x_test.shape}")
# Out:
# Preprocessed training data shape: (71040, 784)
# Preprocessed validation data shape: (17760, 784)
# Preprocessed test data shape: (14800, 784)

# %% [markdown]
# ## 2. Model Implementation

# %%
# Create simple neural network
def create_simple_nn(input_shape, num_classes):
    """
    Create a simple neural network for EMNIST classification.
    
    Requirements:
    - Must use at least 2 dense layers
    - Must include dropout layers
    - Must use categorical crossentropy loss
    
    Goals:
    - Achieve > 80% accuracy on test set
    - Minimize overfitting using dropout
    - Train efficiently with appropriate batch size
    
    Args:
        input_shape: Shape of input data (should be (784,) for flattened 28x28 images)
        num_classes: Number of output classes (26 for letters)
    
    Returns:
        Compiled Keras model
    """
    model = tf.keras.Sequential(
        [
            tf.keras.layers.InputLayer(input_shape=input_shape),
            tf.keras.layers.Dense(128, activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(num_classes, activation='softmax')
        ]
    )
    
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# Create and compile model
model = create_simple_nn(input_shape=(784,), num_classes=26)
model.summary()
# Out:
# d:\homework\DS223\6-neural-nets-ZhangZwaa\.venv\Lib\site-packages\keras\src\layers\core\input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 26)             │         1,690 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 110,426 (431.35 KB)
#  Trainable params: 110,426 (431.35 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 3. Training and Evaluation

# %%
# Define callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=3
    ),
    tf.keras.callbacks.ModelCheckpoint(
        'models/emnist_classifier.keras',
        save_best_only=True
    )
]

# Train model
history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=20,
    batch_size=32,
    callbacks=callbacks
)

# Plot training curves
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Plot accuracy
ax1.plot(history.history['accuracy'], label='Training')
ax1.plot(history.history['val_accuracy'], label='Validation')
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# Plot loss
ax2.plot(history.history['loss'], label='Training')
ax2.plot(history.history['val_loss'], label='Validation')
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 3s 977us/step - accuracy: 0.3422 - loss: 2.2193 - val_accuracy: 0.7328 - val_loss: 0.9175 - learning_rate: 0.0010
# Epoch 2/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 955us/step - accuracy: 0.5938 - loss: 1.3296 - val_accuracy: 0.7723 - val_loss: 0.7591 - learning_rate: 0.0010
# Epoch 3/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 963us/step - accuracy: 0.6357 - loss: 1.1968 - val_accuracy: 0.7926 - val_loss: 0.6817 - learning_rate: 0.0010
# Epoch 4/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 960us/step - accuracy: 0.6611 - loss: 1.1216 - val_accuracy: 0.8025 - val_loss: 0.6511 - learning_rate: 0.0010
# Epoch 5/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 955us/step - accuracy: 0.6702 - loss: 1.0820 - val_accuracy: 0.8078 - val_loss: 0.6273 - learning_rate: 0.0010
# Epoch 6/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 944us/step - accuracy: 0.6815 - loss: 1.0462 - val_accuracy: 0.8145 - val_loss: 0.6091 - learning_rate: 0.0010
# Epoch 7/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 931us/step - accuracy: 0.6903 - loss: 1.0200 - val_accuracy: 0.8232 - val_loss: 0.5832 - learning_rate: 0.0010
# Epoch 8/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 934us/step - accuracy: 0.6929 - loss: 1.0096 - val_accuracy: 0.8227 - val_loss: 0.5785 - learning_rate: 0.0010
# Epoch 9/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 942us/step - accuracy: 0.6968 - loss: 0.9921 - val_accuracy: 0.8253 - val_loss: 0.5713 - learning_rate: 0.0010
# Epoch 10/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 910us/step - accuracy: 0.7028 - loss: 0.9740 - val_accuracy: 0.8245 - val_loss: 0.5665 - learning_rate: 0.0010
# Epoch 11/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 885us/step - accuracy: 0.7037 - loss: 0.9770 - val_accuracy: 0.8295 - val_loss: 0.5495 - learning_rate: 0.0010
# Epoch 12/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 891us/step - accuracy: 0.7091 - loss: 0.9575 - val_accuracy: 0.8322 - val_loss: 0.5549 - learning_rate: 0.0010
# Epoch 13/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 908us/step - accuracy: 0.7080 - loss: 0.9584 - val_accuracy: 0.8311 - val_loss: 0.5448 - learning_rate: 0.0010
# Epoch 14/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 975us/step - accuracy: 0.7082 - loss: 0.9510 - val_accuracy: 0.8358 - val_loss: 0.5379 - learning_rate: 0.0010
# Epoch 15/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 966us/step - accuracy: 0.7131 - loss: 0.9294 - val_accuracy: 0.8376 - val_loss: 0.5332 - learning_rate: 0.0010
# Epoch 16/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 890us/step - accuracy: 0.7169 - loss: 0.9281 - val_accuracy: 0.8382 - val_loss: 0.5268 - learning_rate: 0.0010
# Epoch 17/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 896us/step - accuracy: 0.7165 - loss: 0.9341 - val_accuracy: 0.8364 - val_loss: 0.5283 - learning_rate: 0.0010
# Epoch 18/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 911us/step - accuracy: 0.7188 - loss: 0.9177 - val_accuracy: 0.8368 - val_loss: 0.5265 - learning_rate: 0.0010
# Epoch 19/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 928us/step - accuracy: 0.7200 - loss: 0.9193 - val_accuracy: 0.8409 - val_loss: 0.5241 - learning_rate: 0.0010
# Epoch 20/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 2s 897us/step - accuracy: 0.7244 - loss: 0.9102 - val_accuracy: 0.8389 - val_loss: 0.5260 - learning_rate: 0.0010

# %%
# Evaluate model
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy:.4f}")

# Get predictions
predictions = model.predict(x_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Calculate confusion matrix
cm = tf.math.confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

from sklearn.metrics import precision_score, recall_score, f1_score

# Calculate precision, recall, and F1 score
precision = precision_score(true_labels, predicted_labels, average='weighted')
recall = recall_score(true_labels, predicted_labels, average='weighted')
f1 = f1_score(true_labels, predicted_labels, average='weighted')

# Save metrics
metrics = {
    'model': 'emnist_classifier',
    'accuracy': float(test_accuracy),
    'precision': float(precision),
    'recall': float(recall),
    'f1_score': float(f1),
    'confusion_matrix': cm.numpy().tolist()
}

# Save to file
with open('results/part_1/emnist_classifier_metrics.txt', 'w') as f:
    f.write(f"model: {metrics['model']}\n")
    f.write(f"accuracy: {metrics['accuracy']}\n")
    f.write(f"precision: {metrics['precision']}\n")
    f.write(f"recall: {metrics['recall']}\n")
    f.write(f"f1_score: {metrics['f1_score']}\n")
    f.write(f"confusion_matrix: {metrics['confusion_matrix']}\n")
    f.write("----\n")
# Out:
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - accuracy: 0.8159 - loss: 0.5747
# Test accuracy: 0.8176
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step
# d:\homework\DS223\6-neural-nets-ZhangZwaa\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Progress Checkpoints
#
# 1. **Data Loading**:
#    - [ ] Successfully load EMNIST dataset
#    - [ ] Verify data shapes and ranges
#    - [ ] Visualize sample images
#
# 2. **Preprocessing**:
#    - [ ] Normalize pixel values
#    - [ ] Reshape data for dense layers
#    - [ ] Convert labels to one-hot encoding
#
# 3. **Model Implementation**:
#    - [ ] Create model with required layers
#    - [ ] Verify architecture requirements
#    - [ ] Test model with sample input
#
# 4. **Training**:
#    - [ ] Train model with callbacks
#    - [ ] Monitor training progress
#    - [ ] Save best model
#
# 5. **Evaluation**:
#    - [ ] Calculate performance metrics
#    - [ ] Save metrics in correct format
#    - [ ] Visualize results
#
# ## Common Issues and Solutions
#
# 1. **Data Loading Issues**:
#    - Problem: EMNIST dataset not found
#    - Solution: Check internet connection and TensorFlow installation
#
# 2. **Preprocessing Issues**:
#    - Problem: Shape mismatch in dense layers
#    - Solution: Ensure data is properly reshaped to (n_samples, 784)
#    - Problem: Label encoding errors
#    - Solution: Verify label range and one-hot encoding
#
# 3. **Model Issues**:
#    - Problem: Training instability
#    - Solution: Add batch normalization, reduce learning rate
#    - Problem: Overfitting
#    - Solution: Increase dropout, use data augmentation
#
# 4. **Evaluation Issues**:
#    - Problem: Metrics format incorrect
#    - Solution: Follow the exact format specified
#    - Problem: Performance below threshold
#    - Solution: Adjust architecture, hyperparameters
